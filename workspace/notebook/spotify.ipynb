# %%
# import spotify
# from spotipy.oauth2 import SpotifyClientCredentials
# from spotipy import SpotifyException

# import os
# from IPython.display import Audio
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns


# from kaggle_secrets import UserSecretsClient

# # * Spotify API
#     * Client id: dd85d22904434f088c3368bd80f9e737
#     * Client secret: 645999f592554ae1b7d64e88643e340c

# %%
import csv
import requests
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = 'dd85d22904434f088c3368bd80f9e737'  # Replace with your Client ID
client_secret = '645999f592554ae1b7d64e88643e340c'  # Replace with your Client Secret

# Authenticate with Spotify using Client Credentials
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)


# Authenticate with Spotify using Client Credentials
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

def download_spotify_preview(spotify_id, file_name):
    try:
        # Get track metadata using Spotify ID
        track = sp.track(spotify_id)
        
        # Check if 'preview_url' exists and is not None
        if track.get('preview_url'):
            preview_url = track['preview_url']
            print(f"Downloading preview for Spotify ID: {spotify_id} -> {file_name}")
            
            # Download the preview audio
            response = requests.get(preview_url)
            
            # Save the audio preview as an mp3 file
            with open(file_name, 'wb') as file:
                file.write(response.content)
                
            print(f"Preview for Spotify ID '{spotify_id}' downloaded successfully as {file_name}!")
        else:
            print(f"No preview available for Spotify ID: {spotify_id}")
            
    except Exception as e:
        print(f"Error for Spotify ID {spotify_id}: {e}")

csv_file = 'muse_v3.csv'
with open(csv_file, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)    
    for i, row in enumerate(reader, start=1):
        spotify_id = row['spotify_id']
        if not spotify_id:
            print(f"Skipping row {i} due to missing Spotify ID")
            continue
        file_name = f"{i}.mp3"
        download_spotify_preview(spotify_id, file_name)
# Out:
# No preview available for Spotify ID: 4xkOaSrkexMciUUogZKVTS
# No preview available for Spotify ID: 3fOc9x06lKJBhz435mInlH
# No preview available for Spotify ID: 3Y96xd4Ce0J47dcalLrEC8
# Downloading preview for Spotify ID: 6tqFC1DIOphJkCwrjVzPmg -> 4.mp3
# Preview for Spotify ID '6tqFC1DIOphJkCwrjVzPmg' downloaded successfully as 4.mp3!
# Downloading preview for Spotify ID: 5bU4KX47KqtDKKaLM4QCzh -> 5.mp3
# Preview for Spotify ID '5bU4KX47KqtDKKaLM4QCzh' downloaded successfully as 5.mp3!
# No preview available for Spotify ID: 4Q1w4Ryyi8KNxxaFlOQClK
# No preview available for Spotify ID: 49fT6owWuknekShh9utsjv
# Downloading preview for Spotify ID: 6DoXuH326aAYEN8CnlLmhP -> 8.mp3
# Preview for Spotify ID '6DoXuH326aAYEN8CnlLmhP' downloaded successfully as 8.mp3!
# Downloading preview for Spotify ID: 104YdibC7VQy78xAVmgRYr -> 9.mp3
# Preview for Spotify ID '104YdibC7VQy78xAVmgRYr' downloaded successfully as 9.mp3!
# No preview available for Spotify ID: 5fU6qjmD38P90BMsuqpiuU
# Downloading preview for Spotify ID: 1qxkzHlZBXFv5HfyYqJ8cy -> 11.mp3
# Preview for Spotify ID '1qxkzHlZBXFv5HfyYqJ8cy' downloaded successfully as 11.mp3!
# Downloading preview for Spotify ID: 2ZIJUwprFZrAaZCRKYfAno -> 12.mp3
# Preview for Spotify ID '2ZIJUwprFZrAaZCRKYfAno' downloaded successfully as 12.mp3!
# Downloading preview for Spotify ID: 6xK3sBdRm99g9T8Ov0gjdF -> 13.mp3
# Preview for Spotify ID '6xK3sBdRm99g9T8Ov0gjdF' downloaded successfully as 13.mp3!
# No preview available for Spotify ID: 62wtttQzoIA9HnNmGVd9Yq
# Downloading preview for Spotify ID: 3DaC3oRpGInTU0x8DvdSGp -> 15.mp3
# Preview for Spotify ID '3DaC3oRpGInTU0x8DvdSGp' downloaded successfully as 15.mp3!
# Downloading preview for Spotify ID: 0DxYrFOfiFShTbO2XdFpBX -> 16.mp3
# Preview for Spotify ID '0DxYrFOfiFShTbO2XdFpBX' downloaded successfully as 16.mp3!
# Downloading preview for Spotify ID: 7EZlzu01NzbR1jWEIDSk5T -> 17.mp3
# Preview for Spotify ID '7EZlzu01NzbR1jWEIDSk5T' downloaded successfully as 17.mp3!
# Downloading preview for Spotify ID: 1jRzdY7oUBOhrylNtiMtBD -> 18.mp3
# Preview for Spotify ID '1jRzdY7oUBOhrylNtiMtBD' downloaded successfully as 18.mp3!
# Downloading preview for Spotify ID: 2tdzFXOsJLLI20QdnSqxr1 -> 19.mp3
# Preview for Spotify ID '2tdzFXOsJLLI20QdnSqxr1' downloaded successfully as 19.mp3!
# Downloading preview for Spotify ID: 1Nvy8JAL3DrO0a6xdgJSvv -> 20.mp3
# Preview for Spotify ID '1Nvy8JAL3DrO0a6xdgJSvv' downloaded successfully as 20.mp3!
